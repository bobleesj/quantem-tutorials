# %% [markdown]
# # Non-rigid safety: bounds and knot-count model selection
#
# This advanced tutorial teaches two decisions: **when a motion bound is too
# tight** and **when extra knots are not justified by the specimen**.
#
# The same affine-corrected WS₂ pair is tested first with a deliberately tight
# motion bound, then with a working bound. Every other solver setting is
# identical. Compare the RGB images and metrics before applying one conservative
# result.
#
# Start with `../2d_nonrigid_ws2.ipynb` if knots are new to you.

# %% [markdown]
# ## Import and configure

# %%
import os
from pathlib import Path

import quantem.widget as qw
from quantem.imaging import DriftCorrection

DATA = Path(os.environ.get("QUANTEM_DRIFT_WS2_DATA", "../data/ws2"))
FILES = (
    "0127_VWS2_9h_g_300kv_STEM_HAADF_5.20_Mx_Diffraction.emd",
    "0128_VWS2_9h_g_300kv_STEM_HAADF_5.20_Mx_Diffraction.emd",
)

KNOT_COUNTS = (1, 2, 3)
TIGHT_MAX_SHIFT = 1
WORKING_MAX_SHIFT = 2

# Shared settings keep max_image_shift as the only changed solver choice.
NONRIGID_OPTIONS = dict(
    optimizer="adam",
    num_refine_cycles=64,
    optimizer_steps=30,
    learning_rate=0.1,
    knot_smoothing_sigma=8.0,
    update_fraction=0.8,
    trend_order=1,
    loss="mse",
    early_stop_patience=8,
    min_iterations=4,
    verbose=True,
)

SUMMARY_COLUMNS = [
    "num_knots",
    "common_ncc",
    "yellow",
    "within_scanline_change_px",
]

# Interactive is the recommended default. False uses static/report rendering.
INTERACTIVE = True
VIEW_MODE = "interactive" if INTERACTIVE else "static"

qw.profile()
# Out:
# quantem.widget  0.0.1rc36
#   install       published package
# quantem.gpu     0.0.1rc6
#   install       editable checkout
# quantem         0.1.9
# torch           2.13.0  device=cuda (NVIDIA RTX PRO 6000 Blackwell Max-Q Workstation Edition)
# GPUs            1 visible (CUDA_VISIBLE_DEVICES=1)
#   GPU0           17.7 used / 102 GB  (84 free)
#   torch pool    0.0 live / 0.0 reserved GB
# python          3.14.6

# %% [markdown]
# ## Load the orthogonal EMD pair
#
# `from_emd()` reads scan rotation and calibration from microscope metadata.
# Set `QUANTEM_DRIFT_WS2_DATA` to use another folder with these files.

# %%
drift = DriftCorrection.from_emd(
    DATA / FILES[0],
    DATA / FILES[1],
    verbose=False,
)

# %% [markdown]
# ## Establish the affine starting point
#
# Always solve and inspect affine registration first. Non-rigid correction
# should polish a good affine result, not rescue a bad one.

# %%
drift.correct_affine(
    show_combined=False,
    show_scans=False,
    verbose=False,
)

drift.plot_combined(
    stage=("initial", "affine"),
    interactive=INTERACTIVE,
    width=620,
)

# %% [markdown]
# ## What the safety metric means
#
# The **fast-scan direction** is the direction the beam sweeps along each
# scanline. With two or three knots, neighboring control points may request
# different shifts and bend the correction within that line.
#
# `within_scanline_change_px` is the typical pixel difference between neighboring
# control points. It is not image noise. One knot has no neighbor, so it is zero.
#
# A larger value is not automatically wrong, but it needs visible, physical
# support in the RGB comparison.

# %% [markdown]
# ## Deliberately tight motion bound
#
# This 1 px bound is a negative control. If every candidate remains worse than
# the affine checkpoint, the bound is blocking needed motion. Do not select a
# model from a failed comparison.

# %%
tight_figure, tight_metrics = drift.diagnose_nonrigid(
    num_knots=KNOT_COUNTS,
    max_image_shift=TIGHT_MAX_SHIFT,
    **NONRIGID_OPTIONS,
)
tight_summary = tight_metrics.rename(
    columns={"fast_roughness_px": "within_scanline_change_px"}
)
tight_summary[SUMMARY_COLUMNS]
# Out:
# Diagnosing non-rigid knot counts:   0%|          | 0/3 [00:00<?, ?candidate/s]
# Diagnosing non-rigid knot counts:  33%|███▎      | 1/3 [00:03<00:07,  3.82s/candidate]
# Diagnosing non-rigid knot counts:  67%|██████▋   | 2/3 [00:06<00:03,  3.14s/candidate]
# Diagnosing non-rigid knot counts: 100%|██████████| 3/3 [00:09<00:00,  2.99s/candidate]
# Diagnosing non-rigid knot counts: 100%|██████████| 3/3 [00:09<00:00,  3.10s/candidate]
#    num_knots  common_ncc    yellow  within_scanline_change_px
# 0          1    0.184980  0.494866                   0.000000
# 1          2    0.111604  0.478221                   2.927577
# 2          3    0.155474  0.487271                   1.896822

# %% [markdown]
# ## Working motion bound
#
# The 2 px bound permits the one-knot correction to improve on affine. Two and
# three knots may score still higher, but that alone does not make either model
# preferable.

# %%
working_figure, working_metrics = drift.diagnose_nonrigid(
    num_knots=KNOT_COUNTS,
    max_image_shift=WORKING_MAX_SHIFT,
    **NONRIGID_OPTIONS,
)
working_summary = working_metrics.rename(
    columns={"fast_roughness_px": "within_scanline_change_px"}
)
working_summary[SUMMARY_COLUMNS]
# Out:
# Diagnosing non-rigid knot counts:   0%|          | 0/3 [00:00<?, ?candidate/s]
# Diagnosing non-rigid knot counts:  33%|███▎      | 1/3 [00:05<00:10,  5.00s/candidate]
# Diagnosing non-rigid knot counts:  67%|██████▋   | 2/3 [00:18<00:09,  9.77s/candidate]
# Diagnosing non-rigid knot counts: 100%|██████████| 3/3 [00:31<00:00, 11.35s/candidate]
# Diagnosing non-rigid knot counts: 100%|██████████| 3/3 [00:31<00:00, 10.45s/candidate]
#    num_knots  common_ncc    yellow  within_scanline_change_px
# 0          1    0.368269  0.548379                   0.000000
# 1          2    0.424540  0.560093                   4.444086
# 2          3    0.431358  0.562132                   3.079635

# %% [markdown]
# ## Decide before applying
#
# Prefer the smallest model supported by the images. Reject a candidate when:
#
# - NCC rises but the RGB panel gains periodic red/green fringes;
# - neighboring knots move by several pixels without a visible specimen feature
#   requiring that bend; or
# - the correction approaches a lattice repeat and defects stop corresponding.
#
# For this example, reject the 1 px comparison because it underperforms affine.
# With the 2 px bound, keep one knot because the specimen does not visibly justify
# the several-pixel neighboring-knot changes in the more flexible candidates.

# %%
SELECTED_KNOTS = 1

drift.correct_nonrigid(
    num_knots=SELECTED_KNOTS,
    max_image_shift=WORKING_MAX_SHIFT,
    show_combined=False,
    show_scans=False,
    show_knots=False,
    **NONRIGID_OPTIONS,
)
# Out:
# Solving nonrigid drift (adam):   0%|          | 0/64 [00:00<?, ?it/s]
# Solving nonrigid drift (adam):   0%|          | 0/64 [00:00<?, ?it/s, error=0.01542, best=0.01542]
# Solving nonrigid drift (adam):   0%|          | 0/64 [00:00<?, ?it/s, error=0.01535, best=0.01535]
# Solving nonrigid drift (adam):   0%|          | 0/64 [00:00<?, ?it/s, error=0.01533, best=0.01533]
# Solving nonrigid drift (adam):   5%|▍         | 3/64 [00:00<00:02, 26.11it/s, error=0.01533, best=0.01533]
# Solving nonrigid drift (adam):   5%|▍         | 3/64 [00:00<00:02, 26.11it/s, error=0.01531, best=0.01531]
# Solving nonrigid drift (adam):   5%|▍         | 3/64 [00:00<00:02, 26.11it/s, error=0.01529, best=0.01529]
# Solving nonrigid drift (adam):   5%|▍         | 3/64 [00:00<00:02, 26.11it/s, error=0.01528, best=0.01528]
# Solving nonrigid drift (adam):   9%|▉         | 6/64 [00:00<00:02, 26.54it/s, error=0.01528, best=0.01528]
# Solving nonrigid drift (adam):   9%|▉         | 6/64 [00:00<00:02, 26.54it/s, error=0.01525, best=0.01525]
# Solving nonrigid drift (adam):   9%|▉         | 6/64 [00:00<00:02, 26.54it/s, error=0.01524, best=0.01524]
# Solving nonrigid drift (adam):   9%|▉         | 6/64 [00:00<00:02, 26.54it/s, error=0.01522, best=0.01522]
# Solving nonrigid drift (adam):  14%|█▍        | 9/64 [00:00<00:02, 26.59it/s, error=0.01522, best=0.01522]
# Solving nonrigid drift (adam):  14%|█▍        | 9/64 [00:00<00:02, 26.59it/s, error=0.01521, best=0.01521]
# Solving nonrigid drift (adam):  14%|█▍        | 9/64 [00:00<00:02, 26.59it/s, error=0.01519, best=0.01519]
# Solving nonrigid drift (adam):  14%|█▍        | 9/64 [00:00<00:02, 26.59it/s, error=0.01517, best=0.01517]
# Solving nonrigid drift (adam):  19%|█▉        | 12/64 [00:00<00:01, 26.18it/s, error=0.01517, best=0.01517]
# Solving nonrigid drift (adam):  19%|█▉        | 12/64 [00:00<00:01, 26.18it/s, error=0.01516, best=0.01516]
# Solving nonrigid drift (adam):  19%|█▉        | 12/64 [00:00<00:01, 26.18it/s, error=0.01514, best=0.01514]
# Solving nonrigid drift (adam):  19%|█▉        | 12/64 [00:00<00:01, 26.18it/s, error=0.01512, best=0.01512]
# Solving nonrigid drift (adam):  23%|██▎       | 15/64 [00:00<00:01, 26.13it/s, error=0.01512, best=0.01512]
# Solving nonrigid drift (adam):  23%|██▎       | 15/64 [00:00<00:01, 26.13it/s, error=0.01511, best=0.01511]
# Solving nonrigid drift (adam):  23%|██▎       | 15/64 [00:00<00:01, 26.13it/s, error=0.01509, best=0.01509]
# Solving nonrigid drift (adam):  23%|██▎       | 15/64 [00:00<00:01, 26.13it/s, error=0.01508, best=0.01508]
# Solving nonrigid drift (adam):  28%|██▊       | 18/64 [00:00<00:01, 25.82it/s, error=0.01508, best=0.01508]
# Solving nonrigid drift (adam):  28%|██▊       | 18/64 [00:00<00:01, 25.82it/s, error=0.01506, best=0.01506]
# Solving nonrigid drift (adam):  28%|██▊       | 18/64 [00:00<00:01, 25.82it/s, error=0.01505, best=0.01505]
# Solving nonrigid drift (adam):  28%|██▊       | 18/64 [00:00<00:01, 25.82it/s, error=0.01503, best=0.01503]
# Solving nonrigid drift (adam):  33%|███▎      | 21/64 [00:00<00:01, 25.94it/s, error=0.01503, best=0.01503]
# Solving nonrigid drift (adam):  33%|███▎      | 21/64 [00:00<00:01, 25.94it/s, error=0.01501, best=0.01501]
# Solving nonrigid drift (adam):  33%|███▎      | 21/64 [00:00<00:01, 25.94it/s, error=0.01499, best=0.01499]
# Solving nonrigid drift (adam):  33%|███▎      | 21/64 [00:00<00:01, 25.94it/s, error=0.01498, best=0.01498]
# Solving nonrigid drift (adam):  38%|███▊      | 24/64 [00:00<00:01, 26.00it/s, error=0.01498, best=0.01498]
# Solving nonrigid drift (adam):  38%|███▊      | 24/64 [00:00<00:01, 26.00it/s, error=0.01496, best=0.01496]
# Solving nonrigid drift (adam):  38%|███▊      | 24/64 [00:00<00:01, 26.00it/s, error=0.01494, best=0.01494]
# Solving nonrigid drift (adam):  38%|███▊      | 24/64 [00:01<00:01, 26.00it/s, error=0.01493, best=0.01493]
# Solving nonrigid drift (adam):  42%|████▏     | 27/64 [00:01<00:01, 25.83it/s, error=0.01493, best=0.01493]
# Solving nonrigid drift (adam):  42%|████▏     | 27/64 [00:01<00:01, 25.83it/s, error=0.01491, best=0.01491]
# Solving nonrigid drift (adam):  42%|████▏     | 27/64 [00:01<00:01, 25.83it/s, error=0.0149, best=0.0149]
# Solving nonrigid drift (adam):  42%|████▏     | 27/64 [00:01<00:01, 25.83it/s, error=0.01488, best=0.01488]
# Solving nonrigid drift (adam):  47%|████▋     | 30/64 [00:01<00:01, 25.87it/s, error=0.01488, best=0.01488]
# Solving nonrigid drift (adam):  47%|████▋     | 30/64 [00:01<00:01, 25.87it/s, error=0.01487, best=0.01487]
# Solving nonrigid drift (adam):  47%|████▋     | 30/64 [00:01<00:01, 25.87it/s, error=0.01485, best=0.01485]
# Solving nonrigid drift (adam):  47%|████▋     | 30/64 [00:01<00:01, 25.87it/s, error=0.01484, best=0.01484]
# Solving nonrigid drift (adam):  52%|█████▏    | 33/64 [00:01<00:01, 25.98it/s, error=0.01484, best=0.01484]
# Solving nonrigid drift (adam):  52%|█████▏    | 33/64 [00:01<00:01, 25.98it/s, error=0.01482, best=0.01482]
# Solving nonrigid drift (adam):  52%|█████▏    | 33/64 [00:01<00:01, 25.98it/s, error=0.0148, best=0.0148]
# Solving nonrigid drift (adam):  52%|█████▏    | 33/64 [00:01<00:01, 25.98it/s, error=0.01479, best=0.01479]
# Solving nonrigid drift (adam):  56%|█████▋    | 36/64 [00:01<00:01, 26.05it/s, error=0.01479, best=0.01479]
# Solving nonrigid drift (adam):  56%|█████▋    | 36/64 [00:01<00:01, 26.05it/s, error=0.01477, best=0.01477]
# Solving nonrigid drift (adam):  56%|█████▋    | 36/64 [00:01<00:01, 26.05it/s, error=0.01476, best=0.01476]
# Solving nonrigid drift (adam):  56%|█████▋    | 36/64 [00:01<00:01, 26.05it/s, error=0.01475, best=0.01475]
# Solving nonrigid drift (adam):  61%|██████    | 39/64 [00:01<00:00, 26.06it/s, error=0.01475, best=0.01475]
# Solving nonrigid drift (adam):  61%|██████    | 39/64 [00:01<00:00, 26.06it/s, error=0.01473, best=0.01473]
# Solving nonrigid drift (adam):  61%|██████    | 39/64 [00:01<00:00, 26.06it/s, error=0.01472, best=0.01472]
# Solving nonrigid drift (adam):  61%|██████    | 39/64 [00:01<00:00, 26.06it/s, error=0.0147, best=0.0147]
# Solving nonrigid drift (adam):  66%|██████▌   | 42/64 [00:01<00:00, 26.05it/s, error=0.0147, best=0.0147]
# Solving nonrigid drift (adam):  66%|██████▌   | 42/64 [00:01<00:00, 26.05it/s, error=0.01469, best=0.01469]
# Solving nonrigid drift (adam):  66%|██████▌   | 42/64 [00:01<00:00, 26.05it/s, error=0.01468, best=0.01468]
# Solving nonrigid drift (adam):  66%|██████▌   | 42/64 [00:01<00:00, 26.05it/s, error=0.01466, best=0.01466]
# Solving nonrigid drift (adam):  70%|███████   | 45/64 [00:01<00:00, 26.11it/s, error=0.01466, best=0.01466]
# Solving nonrigid drift (adam):  70%|███████   | 45/64 [00:01<00:00, 26.11it/s, error=0.01465, best=0.01465]
# Solving nonrigid drift (adam):  70%|███████   | 45/64 [00:01<00:00, 26.11it/s, error=0.01464, best=0.01464]
# Solving nonrigid drift (adam):  70%|███████   | 45/64 [00:01<00:00, 26.11it/s, error=0.01463, best=0.01463]
# Solving nonrigid drift (adam):  75%|███████▌  | 48/64 [00:01<00:00, 26.12it/s, error=0.01463, best=0.01463]
# Solving nonrigid drift (adam):  75%|███████▌  | 48/64 [00:01<00:00, 26.12it/s, error=0.01461, best=0.01461]
# Solving nonrigid drift (adam):  75%|███████▌  | 48/64 [00:01<00:00, 26.12it/s, error=0.0146, best=0.0146]
# Solving nonrigid drift (adam):  75%|███████▌  | 48/64 [00:01<00:00, 26.12it/s, error=0.01458, best=0.01458]
# Solving nonrigid drift (adam):  80%|███████▉  | 51/64 [00:01<00:00, 26.00it/s, error=0.01458, best=0.01458]
# Solving nonrigid drift (adam):  80%|███████▉  | 51/64 [00:01<00:00, 26.00it/s, error=0.01457, best=0.01457]
# Solving nonrigid drift (adam):  80%|███████▉  | 51/64 [00:02<00:00, 26.00it/s, error=0.01456, best=0.01456]
# Solving nonrigid drift (adam):  80%|███████▉  | 51/64 [00:02<00:00, 26.00it/s, error=0.01455, best=0.01455]
# Solving nonrigid drift (adam):  84%|████████▍ | 54/64 [00:02<00:00, 25.98it/s, error=0.01455, best=0.01455]
# Solving nonrigid drift (adam):  84%|████████▍ | 54/64 [00:02<00:00, 25.98it/s, error=0.01453, best=0.01453]
# Solving nonrigid drift (adam):  84%|████████▍ | 54/64 [00:02<00:00, 25.98it/s, error=0.01452, best=0.01452]
# Solving nonrigid drift (adam):  84%|████████▍ | 54/64 [00:02<00:00, 25.98it/s, error=0.01451, best=0.01451]
# Solving nonrigid drift (adam):  89%|████████▉ | 57/64 [00:02<00:00, 25.97it/s, error=0.01451, best=0.01451]
# Solving nonrigid drift (adam):  89%|████████▉ | 57/64 [00:02<00:00, 25.97it/s, error=0.0145, best=0.0145]
# Solving nonrigid drift (adam):  89%|████████▉ | 57/64 [00:02<00:00, 25.97it/s, error=0.01449, best=0.01449]
# Solving nonrigid drift (adam):  89%|████████▉ | 57/64 [00:02<00:00, 25.97it/s, error=0.01448, best=0.01448]
# Solving nonrigid drift (adam):  94%|█████████▍| 60/64 [00:02<00:00, 26.01it/s, error=0.01448, best=0.01448]
# Solving nonrigid drift (adam):  94%|█████████▍| 60/64 [00:02<00:00, 26.01it/s, error=0.01447, best=0.01447]
# Solving nonrigid drift (adam):  94%|█████████▍| 60/64 [00:02<00:00, 26.01it/s, error=0.01446, best=0.01446]
# Solving nonrigid drift (adam):  94%|█████████▍| 60/64 [00:02<00:00, 26.01it/s, error=0.01445, best=0.01445]
# Solving nonrigid drift (adam):  98%|█████████▊| 63/64 [00:02<00:00, 25.98it/s, error=0.01445, best=0.01445]
# Solving nonrigid drift (adam):  98%|█████████▊| 63/64 [00:02<00:00, 25.98it/s, error=0.01444, best=0.01444]
# Solving nonrigid drift (adam): 100%|██████████| 64/64 [00:02<00:00, 26.02it/s, error=0.01444, best=0.01444]

# %% [markdown]
# ## Before and after

# %%
drift.plot_combined(
    stage=("initial", "affine", "nonrigid"),
    interactive=INTERACTIVE,
    width=620,
)

# %% [markdown]
# ## Quantitative check

# %%
drift.report()
# Out:
#               Common NCC  Top third  Middle third  Bottom third  Coverage
# Mutual stage
# before          0.066213   0.021732      0.068717      0.073991  0.928105
# affine          0.248270   0.219939      0.276249      0.213979  0.928105
# nonrigid        0.368017   0.348874      0.383339      0.341956  0.928105

# %% [markdown]
# ## Inspect the corrected result
#
# Inspect defects and edges, not only the repeating lattice. The linked
# interactive panels make local zoom, pan, and contrast comparison available
# without changing the correction.

# %%
drift.show(
    mode=VIEW_MODE,
    cmap="gray",
    auto_contrast=True,
    link_contrast=True,
    smooth=False,
    show_fft=False,
)
# Out:
#   Display bin 3×: 2560×2560 → 853×853 (16 MB preview; full-res detail streams on zoom)

# %% [markdown]
# ## Takeaway
#
# Non-rigid model selection is not “highest NCC wins.” First verify that the
# motion bound permits improvement over affine. Then compare candidates from the
# same affine checkpoint and accept extra knots only when the specimen visibly
# requires within-scanline bending.
#
# Regenerate this notebook with:
#
# ```bash
# python tutorials/template/build_2d_nonrigid_safety_ws2_tutorial.py
# ```
